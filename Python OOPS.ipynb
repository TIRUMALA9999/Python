# %%
class car:
    pass

# %%
audiq7=car()

# %%
audiq7

# %%
class car:
    def __init__(self,mileage,year,make,model):
        self.mileage=mileage
        self.year=year
        self.make=make
        self.model=model

# %%
nano=car(20,2020,3245324,"dsfs34")
audiq7=car(10,2020,23432,"2343dfs")

# %%
nano.year
# Out:
# 2020

# %%
class car:
    def __init__(a,m,y,ma,mo):
        a.mileage=m
        a.year=y
        a.make=ma
        a.model=mo

# %%
tata=car(30,3432,234324,'23432ffesd')

# %%
tata.mileage
# Out:
# 30

# %%
tata.year
# Out:
# 3432

# %%
class data:
    def __init__(self,filename,filetype,date,size):
        self.filename=filename
        self.filetype=filetype
        self.date=date
        self.size=size
        
    def _open(self):
        f=open(self.filename,'w')
        f.write('something')
        f.close()
        
    def _read(self):
        f=open(self.filename,'r')
        print(f.read())
        f.close()
        
    def _append(self):
        f=open(self.filename,'a')
        f.write('Appending data to the file')
        f.close()
file1=data('file1','txt','2021-4-11','2MB')

# %%
file1._open()

# %%
file1._read()
# Out:
# something

# %%
file1._append()

# %%
with open('file1','r') as f:
    print(f.read())
# Out:
# somethingAppending data to the file

# %%
print(f.name)
# Out:
# file1

# %%
f.mode
# Out:
# 'r'

# %%
A = ["Hello\n", "Coders\n", "JavaTpoint\n"]  
f1 = open('myfile.txt', 'w')  
f1.writelines(A)  
f1.close()  
f1 = open('myfile.txt', 'r')  
Lines = f1.read() 
print(Lines)
count = 0  
for line in Lines:  
    count += 1  
    print("Line {}: {}".format(count, line.strip()))
# Out:
# Hello
# Coders
# JavaTpoint
#
# Line 1: H
# Line 2: e
# Line 3: l
# Line 4: l
# Line 5: o
# Line 6:
# Line 7: C
# Line 8: o
# Line 9: d
# Line 10: e
# Line 11: r
# Line 12: s
# Line 13:
# Line 14: J
# Line 15: a
# Line 16: v
# Line 17: a
# Line 18: T
# Line 19: p
# Line 20: o
# Line 21: i
# Line 22: n
# Line 23: t
# Line 24:

# %%
A = ["Hello\n", "Coders\n", "JavaTpoint\n"]  
f1 = open('myfile.txt', 'w')  
f1.writelines(A)  
f1.close()  
f1 = open('myfile.txt', 'r')  
Lines = f1.readlines()  
count = 0  
for line in Lines:  
    count += 1  
    print("Line{}: {}".format(count, line.strip()))
# Out:
# Line1: Hello
# Line2: Coders
# Line3: JavaTpoint

# %% [markdown]
# ### OUTPUT FORMATTING

# %%
# Python program showing how to use string modulo operator(%)

print("Geeks : %2d, Portal : %6.2f" % (1, 05.333)) 

print("Total students : %3d, Boys : %2d" % (240, 120)) # print integer value

print("%7.3o" % (25)) # print octal value

print("%10.3E" % (356.08977)) # print exponential value
# Out:
# Geeks :  1, Portal :   5.33
# Total students : 240, Boys : 120
#     031
#  3.561E+02

# %%
# combining positional and keyword arguments
print('Number one portal is {0}, {1}, and {other}.'.format('Geeks', 'For', other ='Geeks'))

# using format() method with number 
print("Geeks :{0:2d}, Portal :{1:8.2f}".format(12, 00.546))

# Changing positional argument
print("Second argument: {1:3d}, first one: {0:7.2f}".format(47.42, 11))

print("Geeks: {a:5d}, Portal: {p:8.2f}".format(a = 453, p = 59.058))
# Out:
# Number one portal is Geeks, For, and Geeks.
# Geeks :12, Portal :    0.55
# Second argument:  11, first one:   47.42
# Geeks:   453, Portal:    59.06

# %%
# using format() method and referring a position of the object
print(f"{'Geeks'} and {'Portal'}")
# Out:
# Geeks and Portal

# %%
string = '  xoxo love xoxo   '

# all <whitespace>,x,o,e characters in the left
# and right of string are removed
print(string.strip(' xoe'))
# Out:
# lov

# %%
string = '  xoxo love xoxo   '

# leading and trailing whitespaces are removed
print(string.strip())
# Out:
# xoxo love xoxo

# %%
try:  
    with open('file2.txt', 'w') as f:  
        f.write('Here we create a new file')  
except FileNotFoundError:  
    print("The file is does not exist")

# %%
# open the file file2.txt in read mode    
fileptr = open("file2.txt","r")    
  
#initially the filepointer is at 0     
print("The filepointer is at byte :",fileptr.tell())    
    
#reading the content of the file    
content = fileptr.read();    
    
#after the read operation file pointer modifies. tell() returns the location of the fileptr.     
    
print("After reading, the filepointer is at:",fileptr.tell())
# Out:
# The filepointer is at byte : 0
# After reading, the filepointer is at: 25

# %%
# open the file file2.txt in read mode    
fileptr = open("file2.txt","r")    
    
#initially the filepointer is at 0     
print("The filepointer is at byte :",fileptr.tell())    
    
#changing the file pointer location to 10.    
fileptr.seek(10)
    
#tell() returns the location of the fileptr.     
print("After reading, the filepointer is at:",fileptr.tell())
# Out:
# The filepointer is at byte : 0
# After reading, the filepointer is at: 10

# %% [raw]
# # This code is used to rename all the filenames in specifies path
# import os
# def main():
#     i = 0
#     path="D:/JavaTpoint/"
#     for filename in os.listdir(path):
#         destination = "new" + str(i) + ".png"
#         source = path + filename
#         destination = path + destination
#         os.rename(source, destination)
#         i += 1
#
# if __name__ == '__main__':
#     main()

# %%
# It can list all the photos in my computer D drive photos folder
import os
os.listdir('D:\photos')
# Out:
# ['147762.jpg',
#  '147763.jpg',
#  '147764.jpg',
#  '147777.jpg',
#  '147778.jpg',
#  '149417.jpg',
#  '149418.jpg',
#  '149419.jpg',
#  '149420.jpg',
#  '149421.jpg',
#  '149423.jpg',
#  '149424.jpg',
#  '149426.jpg',
#  '149846.jpg',
#  '149943.jpg',
#  '149958.jpg',
#  '150013.jpg',
#  '150017.jpg',
#  '150018.jpg',
#  '150053.jpg',
#  '150054.jpg',
#  '150055.jpg',
#  '150056.jpg',
#  '150057.jpg',
#  '150058.jpg',
#  '150059.jpg',
#  '150063.jpg',
#  '150064.jpg',
#  '150067.jpg',
#  '150241.jpg',
#  '150242.jpg',
#  '150500.jpg',
#  '150588.jpg',
#  '152470.jpg',
#  '152483.jpg',
#  '152484.jpg',
#  '152485.jpg',
#  '152498.jpg',
#  '152500.jpg',
#  '152503.jpg',
#  '152506.jpg',
#  '152573.jpg',
#  '152575.jpg',
#  '152576.jpg',
#  '152577.jpg',
#  '152579.jpg',
#  '152581.jpg',
#  '152582.jpg',
#  '152585.jpg',
#  '152586.jpg',
#  '152588.jpg',
#  '152667.jpg',
#  '152668.jpg',
#  '152669.jpg',
#  '152675.jpg',
#  '152906.jpg',
#  '262866.jpg',
#  '262869.jpg',
#  '262872.jpg',
#  '262875.jpg',
#  '262878.jpg',
#  '262881.jpg',
#  '262884.jpg',
#  '262901.jpg',
#  '263533.jpg',
#  '263569.jpg',
#  '263572.jpg',
#  '263575.jpg',
#  '263578.jpg',
#  '263581.jpg',
#  '263584.jpg',
#  '263587.jpg',
#  '263590.jpg',
#  '263593.jpg',
#  '263596.jpg',
#  '263599.jpg',
#  '263602.jpg',
#  '263605.jpg',
#  '263608.jpg',
#  '263611.jpg',
#  '263614.jpg',
#  '263617.jpg',
#  '263620.jpg',
#  '263623.jpg',
#  '263626.jpg',
#  '263629.jpg',
#  '263632.jpg',
#  '263635.jpg',
#  '263638.jpg',
#  '263641.jpg',
#  '263644.jpg',
#  '263647.jpg',
#  '263650.jpg',
#  '264905.jpg',
#  '264908.jpg',
#  '264911.jpg',
#  '264991.jpg',
#  '265031.jpg',
#  '265047.jpg',
#  '265050.jpg',
#  '265053.jpg',
#  '265062.jpg',
#  '265076.jpg',
#  '265084.jpg',
#  '265093.jpg',
#  '265096.jpg',
#  '265099.jpg',
#  '265102.jpg',
#  '265105.jpg',
#  '265114.jpg',
#  '265117.jpg',
#  '265120.jpg',
#  '265129.jpg',
#  '265132.jpg',
#  '265144.jpg',
#  '265147.jpg',
#  '265150.jpg',
#  '265165.jpg',
#  '265168.jpg',
#  '265171.jpg',
#  '265174.jpg',
#  '265177.jpg',
#  '265180.jpg',
#  '265183.jpg',
#  '265192.jpg',
#  '265201.jpg',
#  '265204.jpg',
#  '265219.jpg',
#  '265222.jpg',
#  '265225.jpg',
#  '265228.jpg',
#  '265275.jpg',
#  '265278.jpg',
#  '265284.jpg',
#  '265287.jpg',
#  '265302.jpg',
#  '265305.jpg',
#  '265308.jpg',
#  '265311.jpg',
#  '265326.jpg',
#  '265332.jpg',
#  '265335.jpg',
#  '265338.jpg',
#  '265344.jpg',
#  '265389.jpg',
#  '265395.jpg',
#  '265401.jpg',
#  '265404.jpg',
#  '265434.jpg',
#  '265478.jpg',
#  '270440.jpg',
#  '270443.jpg',
#  '270446.jpg',
#  '270449.jpg',
#  '270552.jpg',
#  '270555.jpg',
#  '270558.jpg',
#  '270651.jpg',
#  '270654.jpg',
#  '270657.jpg',
#  '270660.jpg',
#  '270663.jpg',
#  '270666.jpg',
#  '270669.jpg',
#  '270672.jpg',
#  '270675.jpg',
#  '270678.jpg',
#  '270681.jpg',
#  '270684.jpg',
#  '270687.jpg',
#  '270690.jpg',
#  '270693.jpg',
#  '270696.jpg',
#  '270699.jpg',
#  '270702.jpg',
#  '270705.jpg',
#  '270708.jpg',
#  '270711.jpg',
#  '270714.jpg',
#  '270717.jpg',
#  '270720.jpg',
#  '270723.jpg',
#  '270726.jpg',
#  '270729.jpg',
#  '270732.jpg',
#  '270735.jpg',
#  '270738.jpg',
#  '270741.jpg',
#  '328361.jpg',
#  '328367.jpg',
#  '328370.jpg',
#  '328373.jpg',
#  '328379.jpg',
#  '328385.jpg',
#  '328723.jpg',
#  '328729.jpg',
#  '328732.jpg',
#  '328819.jpg',
#  '328822.jpg',
#  '328824.jpg',
#  '328825.jpg',
#  '328828.jpg',
#  '328921.jpg',
#  '328924.jpg',
#  '329316.jpg',
#  '498.jpg',
#  '500.jpg',
#  '6521.jpg',
#  '7517.jpg',
#  '7518.jpg',
#  '866.jpg',
#  'dog.webp',
#  'IMG_20191013_100811.jpg',
#  'IMG_20191026_190244.jpg',
#  'IMG_20191027_133353.jpg',
#  'IMG_20191027_134042.jpg',
#  'IMG_20191029_163455.jpg',
#  'IMG_20191029_163513.jpg',
#  'IMG_20191031_121535.jpg',
#  'IMG_20191110_161720.jpg',
#  'IMG_20191114_175007.jpg',
#  'IMG_20191114_175501.jpg',
#  'IMG_20191114_175515.jpg',
#  'IMG_20191114_175527.jpg',
#  'IMG_20191114_175538.jpg',
#  'IMG_20191114_175550.jpg',
#  'IMG_20191114_175619.jpg',
#  'IMG_20191114_175633.jpg',
#  'IMG_20191114_175701.jpg',
#  'IMG_20191114_175718.jpg',
#  'IMG_20191114_175729.jpg',
#  'IMG_20191114_175740.jpg',
#  'IMG_20191124_123339.jpg',
#  'IMG_20191127_171610.jpg',
#  'IMG_20191129_184624.jpg',
#  'IMG_20191129_190227.jpg',
#  'IMG_20191130_084159.jpg',
#  'IMG_20191130_094505.jpg',
#  'IMG_20191130_111138.jpg',
#  'IMG_20191130_184722.jpg',
#  'IMG_20191205_103344.jpg',
#  'IMG_20191205_103401.jpg',
#  'IMG_20191207_105421.jpg',
#  'IMG_20191212_173950.jpg',
#  'IMG_20191220_195323.jpg',
#  'IMG_20191220_195352.jpg',
#  'IMG_20191221_193630.jpg',
#  'IMG_20191223_124352.jpg',
#  'IMG_20200121_092042.jpg',
#  'IMG_20200121_180248.jpg',
#  'IMG_20200204_162947.jpg',
#  'IMG_20200224_180045.jpg',
#  'IMG_20200228_132245.jpg',
#  'IMG_20200305_165852.jpg',
#  'IMG_20200305_201253.jpg',
#  'IMG_20200411_094431.jpg',
#  'IMG_20200414_125825.jpg',
#  'IMG_20200521_142330.jpg',
#  'IMG_20200524_143414.jpg',
#  'IMG_20200702_182453.jpg',
#  'IMG_20200904_060252.jpg',
#  'IMG_20200916_124737.jpg',
#  'IMG_20201006_132123.jpg',
#  'IMG_20201007_220548.jpg',
#  'IMG_20201008_154623.jpg',
#  'IMG_20201111_191150.jpg',
#  'IMG_20201111_191258.jpg',
#  'IMG_20201111_194524.jpg',
#  'IMG_20201111_195258.jpg',
#  'IMG_20201112_115656.jpg',
#  'IMG_20201112_115722.jpg',
#  'IMG_20201208_181053.jpg',
#  'IMG_20201212_165931.jpg',
#  'IMG_20201214_123533.jpg',
#  'IMG_20210108_132010.jpg',
#  'IMG_20210131_142618.jpg',
#  'IMG_20210131_142702.jpg',
#  'IMG_20210131_143158.jpg',
#  'IMG_20210201_175856.jpg',
#  'IMG_20210215_144507.jpg',
#  'IMG_20210215_144513.jpg',
#  'IMG_20210220_082819.jpg',
#  'IMG_20210220_082832.jpg',
#  'IMG_20210220_082946.jpg',
#  'IMG_20210220_082953.jpg',
#  'IMG_20210220_083029.jpg',
#  'IMG_20210220_083356.jpg',
#  'IMG_20210220_083631.jpg',
#  'IMG_20210220_083640.jpg',
#  'IMG_20210302_194845.jpg',
#  'IMG_20210302_194936.jpg',
#  'IMG_20210307_205725.jpg',
#  'IMG_20210316_192930.jpg',
#  'IMG_20210322_102951.jpg',
#  'IMG_20210322_103725.jpg',
#  'IMG_20210417_211314.jpg',
#  'IMG_20210417_211331.jpg',
#  'IMG_20210417_211353.jpg',
#  'IMG_20210417_211401.jpg',
#  'IMG_20210421_110544.jpg',
#  'IMG_20210527_105307.jpg',
#  'IMG_20210708_082116.jpg',
#  'IMG_20210725_195656.jpg',
#  'IMG_20210725_195704.jpg',
#  'IMG_20210819_162857.jpg',
#  'IMG_20210819_162917.jpg',
#  'IMG_20210819_163232.jpg',
#  'IMG_20210822_152453.jpg',
#  'IMG_20210828_163221.jpg',
#  'IMG_20210903_164638.jpg',
#  'IMG_20210903_164644.jpg',
#  'IMG_20211013_094700.jpg',
#  'IMG_20211013_094704.jpg',
#  'IMG_20211013_094710.jpg',
#  'IMG_20211013_100441.jpg',
#  'IMG_20211013_100451.jpg',
#  'IMG_20211013_100547.jpg',
#  'IMG_20211013_100715.jpg',
#  'IMG_20211013_100725.jpg',
#  'IMG_20211013_100808.jpg',
#  'IMG_20211013_100919.jpg',
#  'IMG_20211013_100926.jpg',
#  'IMG_20211013_101658.jpg',
#  'IMG_20211013_101730.jpg',
#  'IMG_20211013_104502.jpg',
#  'IMG_20211013_104507.jpg',
#  'IMG_20211013_104538.jpg',
#  'IMG_20211013_104620.jpg',
#  'IMG_20211013_104626.jpg',
#  'IMG_20211013_104758.jpg',
#  'IMG_20211013_104818.jpg',
#  'IMG_20211013_105810.jpg',
#  'IMG_20211013_105831.jpg',
#  'IMG_20211013_134807.jpg',
#  'IMG_20211013_134919.jpg',
#  'IMG_20211013_134928.jpg',
#  'IMG_20211013_140520.jpg',
#  'IMG_20211013_140530.jpg',
#  'IMG_20211013_140545.jpg',
#  'IMG_20211013_140551.jpg',
#  'IMG_20211013_140553.jpg',
#  'IMG_20211013_153545.jpg',
#  'IMG_20211013_153554.jpg',
#  'IMG_20211013_153617.jpg',
#  'IMG_20211013_153631.jpg',
#  'IMG_20211013_153632.jpg',
#  'IMG_20211015_102508.jpg',
#  'IMG_20211015_102515.jpg',
#  'IMG_20211102_214252.jpg',
#  'IMG_20211104_193445.jpg',
#  'IMG_20211110_174329.jpg',
#  'IMG_20211110_174340.jpg',
#  'IMG_20211120_183014.jpg',
#  'IMG_20211120_183026.jpg',
#  'IMG_20211126_083740.jpg',
#  'IMG_20211126_083752.jpg',
#  'IMG_20211126_084841.jpg',
#  'IMG_20211126_084848.jpg',
#  'IMG_20221222_093712.jpg',
#  'IMG_20221222_093714.jpg',
#  'IMG_20221222_093714_1.jpg',
#  'IMG_20221222_093720.jpg',
#  'IMG_20221222_093722.jpg',
#  'IMG_20221222_093723.jpg',
#  'IMG_20221222_093812.jpg',
#  'IMG_20221222_093815.jpg',
#  'IMG_20221222_093816.jpg',
#  'IMG_20221223_203416.jpg',
#  'IMG_20221225_190839_277.jpg',
#  'IMG_20221225_190845_289.jpg',
#  'IMG_20221225_190850_349.jpg',
#  'IMG_20221225_190858_799.jpg',
#  'IMG_20221225_190903_366.jpg',
#  'IMG_20230103_124659.jpg',
#  'IMG_20230106_155138.jpg',
#  'IMG_20230106_155218.jpg',
#  'IMG_20230112_105829.jpg',
#  'IMG_20230112_105906.jpg',
#  'IMG_20230112_105912.jpg',
#  'IMG_20230112_110039.jpg',
#  'IMG_20230112_110045.jpg',
#  'IMG_20230118_103058.jpg',
#  'IMG_20230119_202047.jpg',
#  'IMG_20230124_152133.jpg',
#  'IMG_20230124_152137.jpg',
#  'IMG_20230124_152149.jpg',
#  'IMG_20230124_181902.jpg',
#  'IMG_20230124_181916.jpg',
#  'IMG_20230124_181935.jpg',
#  'IMG_20230124_181947.jpg',
#  'IMG_20230126_150349.jpg',
#  'IMG_20230126_173656.jpg',
#  'IMG_20230126_195108.jpg',
#  'IMG_20230130_130545.jpg',
#  'IMG_20230131_125754.jpg',
#  'IMG_20230131_151704.jpg',
#  'IMG_20230202_082115.jpg',
#  'IMG_20230202_192612.jpg',
#  'IMG_20230203_135512.jpg',
#  'IMG_20230203_135516.jpg',
#  'IMG_20230203_165027.jpg',
#  'IMG_20230203_165240.jpg',
#  'IMG_20230203_165253.jpg',
#  'IMG_20230203_165529.jpg',
#  'IMG_20230203_165541.jpg',
#  'IMG_20230203_192300.jpg',
#  'IMG_20230203_192323.jpg',
#  'IMG_20230203_222946.jpg',
#  'IMG_20230203_222949.jpg',
#  'IMG_20230203_223014.jpg',
#  'IMG_20230203_223019.jpg',
#  'IMG_20230203_223747.jpg',
#  'IMG_20230203_223805.jpg',
#  'IMG_20230209_191946.jpg',
#  'IMG_20230210_064207.jpg',
#  'IMG_20230210_064213.jpg',
#  'IMG_20230210_064217.jpg',
#  'IMG_20230210_064221.jpg',
#  'IMG_20230210_064434.jpg',
#  'IMG_20230210_064443.jpg',
#  'IMG_20230210_064457.jpg',
#  'IMG_20230210_064501.jpg',
#  'IMG_20230210_064513.jpg',
#  'IMG_20230210_064522.jpg',
#  'IMG_20230210_064532.jpg',
#  'IMG_20230210_065203.jpg',
#  'IMG_20230210_065219.jpg',
#  'IMG_20230210_065227.jpg',
#  'IMG_20230210_071758.jpg',
#  'IMG_20230210_071802.jpg',
#  'IMG_20230210_071810.jpg',
#  'IMG_20230216_191324.jpg',
#  'IMG_20230217_123259.jpg',
#  'IMG_20230217_123305.jpg',
#  'IMG_20230217_123318.jpg',
#  'IMG_20230217_123325.jpg',
#  'IMG_20230219_115237.jpg',
#  'IMG_20230219_193145.jpg',
#  'IMG_20230219_193434.jpg',
#  'IMG_20230219_193441.jpg',
#  'IMG_20230219_193502.jpg',
#  'IMG_20230225_115844.jpg',
#  'IMG_20230228_104729.jpg',
#  'IMG_20230228_104737.jpg',
#  'IMG_20230228_201206.jpg',
#  'IMG_20230228_201339.jpg',
#  'IMG_20230302_083810.jpg',
#  'IMG_20230308_182134.jpg',
#  'IMG_20230308_182138.jpg',
#  'IMG_20230308_182145.jpg',
#  'IMG_20230308_182149.jpg',
#  'IMG_20230309_160609.jpg',
#  'IMG_20230309_160611.jpg',
#  'IMG_20230310_105426.jpg',
#  'IMG_20230310_105428.jpg',
#  'IMG_20230310_115603.jpg',
#  'IMG_20230310_115605.jpg',
#  'IMG_20230310_115609.jpg',
#  'IMG_20230310_115614.jpg',
#  'IMG_20230310_115616.jpg',
#  'IMG_20230311_041900.jpg',
#  'IMG_20230311_041913.jpg',
#  'IMG_20230311_042014.jpg',
#  'IMG_20230311_042041.jpg',
#  'IMG_20230313_163114.jpg',
#  'IMG_20230313_163127.jpg',
#  'IMG_20230313_163131.jpg',
#  'IMG_20230313_163210.jpg',
#  'IMG_20230314_174656.jpg',
#  'IMG_20230314_174933.jpg',
#  'IMG_20230314_175102.jpg',
#  'IMG_20230314_183027.jpg',
#  'IMG_20230325_091957.jpg',
#  'IMG_20230325_092010.jpg',
#  'IMG_20230325_113947.jpg',
#  'IMG_20230325_115651.jpg',
#  'IMG_20230325_144713.jpg',
#  'IMG_20230325_144717.jpg',
#  'IMG_20230326_205307.jpg',
#  'IMG_20230326_214818.jpg',
#  'IMG_20230326_214846.jpg',
#  'IMG_20230327_205321.jpg',
#  'IMG_20230327_205336.jpg',
#  'IMG_20230327_205343.jpg',
#  'IMG_20230327_205350.jpg',
#  'IMG_20230328_105834.jpg',
#  'IMG_20230328_105840.jpg',
#  'IMG_20230328_105843.jpg',
#  'IMG_20230401_112208.jpg',
#  'IMG_20230401_112406.jpg',
#  'IMG_20230401_135218.jpg',
#  'IMG_20230401_135227.jpg',
#  'training.webp',
#  'video_20221218_164203.mp4',
#  'video_20221218_164210.mp4',
#  'video_20230202_142021.mp4',
#  'video_20230302_171631.mp4',
#  'video_20230310_105440.mp4',
#  'video_20230310_111330.mp4',
#  'video_20230317_153900.mp4']

# %%
#Removing the file
import os  
if os.path.exists("file3.txt "):  
    os.remove("file3.txt ")  
else:  
    print("This file is not existed")
# Out:
# This file is not existed

# %%
import os    
    
#creating a new directory with the name new    
os.mkdir("new")

# %%
import os  
path = '/D:/JavaTpoint'   
try:  
    os.mkdir(path)  
except OSError as error:  
    print(error)
# Out:
# [WinError 123] The filename, directory name, or volume label syntax is incorrect: '/D:/JavaTpoint'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %%
import os  
dir = "JavaTpoint"  
parent = "/D:/User/Documents"  
path = os.path.join(parent, dir)  
try:  
    os.rmdir(path)  
    print("The directory '%s' is successfully removed" %dir)  
except OSError as error:  
    print(error)  
    print("The directory '%s' cannot be removed successfully" %dir)
# Out:
# [WinError 123] The filename, directory name, or volume label syntax is incorrect: '/D:/User/Documents\\JavaTpoint'
# The directory 'JavaTpoint' cannot be removed successfully

# %% [markdown]
# ## Python program to copy one file data to another file

# %%
# open both files 
with open('file1.txt','r') as firstfile, open('file2.txt','a') as secondfile: 
     # read content from first file 
    for line in firstfile: 
            # append content to second file 
            secondfile.write(line)

# %%
# import module 
import shutil 

# use copyfile() 
shutil.copyfile('file1.txt','file2.txt')
# Out:
# 'file2.txt'

# %%
temperatures=[10,-20,-289,100]    
def c_to_f(c):    
    if c< -273.15:    
        return "That temperature doesn't make sense!"    
    else:    
        f=c*9/5+32    
        return f    
for t in temperatures:    
    print(c_to_f(t))
# Out:
# 50.0
# -4.0
# That temperature doesn't make sense!
# 212.0

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### try except statement

# %%
# Python code to catch an exception and handle it using try and except code blocks  
   
a = ["Python", "Exceptions", "try and except"]  
try:  
    #looping through the elements of the array a, choosing a range that goes beyond the length of the array  
     for i in range( 4 ):  
        print( "The index and element from the array is", i, a[i] )  
#if an error occurs in the try block, then except block will be executed by the Python interpreter       
except:  
    print ("Index out of range")
# Out:
# The index and element from the array is 0 Python
# The index and element from the array is 1 Exceptions
# The index and element from the array is 2 try and except
# Index out of range

# %% [markdown]
# ### Raising an error using 'raise' keyword
#
# ### If a condition does not meet our criteria but is correct according to the Python interpreter, we can intentionally raise an exception using the raise keyword. We can use a customized exception in conjunction with the statement.

# %%
num = [3, 4, 5, 7]  
if len(num) > 3:  
    raise Exception( f"Length of the given list must be less than or equal to 3 but is {len(num)}" )
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 num = [3, 4, 5, 7]
#       2 if len(num) > 3:
# ----> 3     raise Exception( f"Length of the given list must be less than or equal to 3 but is {len(num)}" )
#
# Exception: Length of the given list must be less than or equal to 3 but is 4

# %% [markdown]
# ## assert statement

# %%
#Python program to show how to use assert keyword  
# defining a function  
def square_root( Number ):  
    assert ( Number > 0), "Give a positive integer"    #This statement should be true to run program without any interruption
    return Number**(1/2)  
  
#Calling function and passing the values  
print( square_root(-11) )  
print( square_root(-2) )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 8
#       5     return Number**(1/2)
#       7 #Calling function and passing the values
# ----> 8 print( square_root(-11) )
#       9 print( square_root(-2) )
#
# Cell In[10], line 4, in square_root(Number)
#       3 def square_root( Number ):
# ----> 4     assert ( Number > 0), "Give a positive integer"
#       5     return Number**(1/2)
#
# AssertionError: Give a positive integer

# %% [markdown]
# ### finally keyword in python
#
# ### The finally keyword is available in Python, and it is always used after the try-except block. The finally code block is always executed after the try block has terminated normally or after the try block has terminated for some other reason.

# %%
try:  
    div = 4 // 0    
    print( div )  
# this block will handle the exception raised  
except ZeroDivisionError:  
    print( "Atempting to divide by zero" )  
# this will always be executed no matter exception is raised or not  
finally:  
    print( 'This is code of finally clause' )
# Out:
# Atempting to divide by zero
# This is code of finally clause

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %%
os.listdir()
# Out:
# ['.bash_history',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.docker',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.lesshst',
#  '.matplotlib',
#  '.nvm',
#  '.spyder-py3',
#  '.streamlit',
#  '.viminfo',
#  '.vscode',
#  '3D Objects',
#  '5501 assignment 3.ipynb',
#  '5501 python coding examples.ipynb',
#  '5505 naive bayes assignment.ipynb',
#  'all_sentiment_shuffled.docx',
#  'ALS_TestingData_78.csv',
#  'ALS_TrainingData_2223.csv',
#  'anaconda3',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'Assignment1.1.ipynb',
#  'basics.ipynb',
#  'breast cancer data.csv',
#  'Contacts',
#  'Cookies',
#  'CROP SELECTION.ipynb',
#  'Crop_recommendation.csv',
#  'Data Sciecne Ecosystem.ipynb',
#  'Data science ecosystem.ipynb',
#  'Data_Science_Folder',
#  'Demo',
#  'diabetes (1).csv',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'file1',
#  'file1.txt',
#  'file2.txt',
#  'final naive bayes 5505.ipynb',
#  'gender prediction-Copy1.ipynb',
#  'gender prediction.ipynb',
#  'gender predictionproject.ipynb',
#  'Gradient descent.ipynb',
#  'Jedi',
#  'linear regression model.ipynb',
#  'Links',
#  'Local Settings',
#  'LogisticRegression 5505.ipynb',
#  'Microsoft',
#  'monet.csv',
#  'Music',
#  'My Documents',
#  'myfile.txt',
#  'NetHood',
#  'new',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TM.blf',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'output.txt',
#  'Postman',
#  'Postman Agent',
#  'PrintHood',
#  'product_details',
#  'product_details.csv',
#  'product_details.xlsx',
#  'PycharmProjects',
#  'python basic programming.ipynb',
#  'Python OOPS.ipynb',
#  'python practice.ipynb',
#  'Python Programming.ipynb',
#  'random forest assignment.ipynb',
#  'Recent',
#  'RequestsVenv',
#  'Saved Games',
#  'scikit_learn_data',
#  'Searches',
#  'self.filename',
#  'SendTo',
#  'simpleapp.py',
#  'smartknowerpythonpractice',
#  'source',
#  'Start Menu',
#  'temp',
#  'Templates',
#  'text',
#  'TitanicDataset.csv',
#  'tmp',
#  'Tracing',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'Videos',
#  'web scraping',
#  'web scraping using beautiful soup.ipynb',
#  'web scraping using scrapy.ipynb',
#  'winequality-red.csv',
#  'Yegineni Tirumala Teja 5501 assignment 2.ipynb',
#  'Yegineni_TirumalaTeja.ipynb',
#  'Yegineni_Tirumala_Teja.ipynb']

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %%
filepath=os.path.abspath('generate_python_files.py')

# %%
filepath
# Out:
# 'C:\\Users\\Lenovo\\generate_python_files.py'

# %%
filepath.rsplit('\\',maxsplit=1)
# Out:
# ['C:\\Users\\Lenovo', 'generate_python_files.py']

# %%
os.path.dirname(filepath)
# Out:
# 'C:\\Users\\Lenovo'

# %%
os.path.basename(filepath)
# Out:
# 'generate_python_files.py'

# %%
os.path.isfile('generate_python_files')
# Out:
# False
